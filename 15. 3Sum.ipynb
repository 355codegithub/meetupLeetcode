# %%
#15. 3Sum

# %% [markdown]
# #Software Development Lifecycle
# #Planning:
# nums=[1,2,3,4,5,6,7,8,9]
# [nums[i], nums[j], nums[k]]
# nums[i] + nums[j] + nums[k] == 0
#
# #Requirements:
# i != j, i != k, and j != k
#
# #Design:
# Steps
# x1: Go Through List Find Groups of 3.
# x   Q: Do I need to find all 3? No. I'll just start 2.
# x   Start with combinations of two [0,0,] [0,1] [0,2]
# x2: Check see if third number summing to 0 is in list
# 3: Check Indices are not Equal
# 4: Check not a duplicate in the Final List of Lists.
#     If yes, add to answer list.
#
# #Coding:
#
# #Testing:
# [-1,0,1,2,-1,-4] Solution: [[-1,-1,2],[-1,0,1]]
# [0,1,1]
# [0,0,0]
# 3 <= nums.length <= 3000
# -105 <= nums[i] <= 105
#
# #Verification
# Time Complexity
#
#
# #Done!

# %%
def threeSum(nums):
    nums=sorted(nums)
    print(nums)
    numsLength=len(nums)
    print(numsLength)
    finalTripletList=[]
    tripletList=[]
    
    
    for index1 in range(numsLength):
        for index2 in range(index1+1,numsLength):
            #print("Individual Numbers:")
            num3=-(nums[index1]+nums[index2])
            print(nums[index1])
            print(nums[index2])
            print("num3")
            print(num3)
            if num3 in nums:
                if index1!=index2 and index2!=nums.index(num3):
                    print("num3 is in the list")
                    tripletList=[nums[index1],nums[index2],num3]
                    tripletList=sorted(tripletList)
                    print(tripletList)
                    if tripletList not in finalTripletList:
                        finalTripletList.append(tripletList)
                        print("FINAL ANSWER:")
                        print(finalTripletList)

# %%
#inputList=[-1,0,1,2,-1,-4]
inputList=[1,3,6,8,3,7,35,26,2,7,14,12,15,9,8,-4,-1,-2,-6,-7,-8,-11,-14,-15,-12,-19]

# %%
threeSum(inputList)
#Note: I have a lot of duplicate index pairs
#next: remove Duplicates.
# Out:
# [-19, -15, -14, -12, -11, -8, -7, -6, -4, -2, -1, 1, 2, 3, 3, 6, 7, 7, 8, 8, 9, 12, 14, 15, 26, 35]
# 26
# -19
# -15
# num3
# 34
# -19
# -14
# num3
# 33
# -19
# -12
# num3
# 31
# -19
# -11
# num3
# 30
# -19
# -8
# num3
# 27
# -19
# -7
# num3
# 26
# num3 is in the list
# [-19, -7, 26]
# FINAL ANSWER:
# [[-19, -7, 26]]
# -19
# -6
# num3
# 25
# -19
# -4
# num3
# 23
# -19
# -2
# num3
# 21
# -19
# -1
# num3
# 20
# -19
# 1
# num3
# 18
# -19
# 2
# num3
# 17
# -19
# 3
# num3
# 16
# -19
# 3
# num3
# 16
# -19
# 6
# num3
# 13
# -19
# 7
# num3
# 12
# num3 is in the list
# [-19, 7, 12]
# FINAL ANSWER:
# [[-19, -7, 26], [-19, 7, 12]]
# -19
# 7
# num3
# 12
# num3 is in the list
# [-19, 7, 12]
# -19
# 8
# num3
# 11
# -19
# 8
# num3
# 11
# -19
# 9
# num3
# 10
# -19
# 12
# num3
# 7
# num3 is in the list
# [-19, 7, 12]
# -19
# 14
# num3
# 5
# -19
# 15
# num3
# 4
# -19
# 26
# num3
# -7
# num3 is in the list
# [-19, -7, 26]
# -19
# 35
# num3
# -16
# -15
# -14
# num3
# 29
# -15
# -12
# num3
# 27
# -15
# ...
